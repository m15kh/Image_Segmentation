# %%
import cv2

# %%
image = cv2.imread('/home/ubuntu/m15kh/U_NET/U_Net_v2/30331320240684_porg_1.png')  # Replace 'path_to_image.jpg' with the actual path to your image
print(image.shape)
import matplotlib.pyplot as plt

# Convert BGR image (OpenCV format) to RGB for displaying with matplotlib
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display the image
plt.imshow(image_rgb)
plt.axis('off')  # Turn off axis
plt.show()
# Out:
# (2600, 2400, 3)
